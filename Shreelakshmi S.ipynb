# %% [markdown]
# # **Title**

# %% [markdown]
# Banking Customer Churn Prediction Dataset

# %% [markdown]
# #**Problem Statement**

# %% [markdown]
# The goal of this project is to analyze a banking dataset to understand why customers leave the bank (churn). By performing Exploratory Data Analysis (EDA), we identify patterns and factors that influence customer churn and provide insights to help banks improve customer retention.

# %% [markdown]
# # **Project Objectives**

# %% [markdown]
# •To understand the structure and features of the banking customer churn dataset
#
# •To perform data cleaning and preparation for accurate analysis
#
# •To conduct univariate, bivariate, and multivariate exploratory data analysis
#
# •To identify patterns and trends related to customer churn
#
# •To analyze the factors that influence customers to leave the bank
#
# •To summarize key insights for better decision-making
#
# •To provide conclusions and actionable recommendations to reduce churn

# %% [markdown]
# # **Tools and Libraries**

# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

sns.set_style("whitegrid")

# %% [markdown]
# # **Dataset Loading**

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Copy of Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# # **Data Dictionary**

# %% [markdown]
# | Column Name | Description | Data Type |
# |-------------|-------------|-----------|
# | CreditScore | Customer credit score | Numerical |
# | Geography | Country of the customer | Categorical |
# | Gender | Gender of the customer | Categorical |
# | Age | Age of the customer | Numerical |
# | Tenure | Years customer stayed with bank | Numerical |
# | Balance | Account balance | Numerical |
# | NumOfProducts | Number of bank products used | Numerical |
# | HasCrCard | Customer has credit card (Yes/No) | Categorical |
# | IsActiveMember | Customer active status | Categorical |
# | EstimatedSalary | Estimated annual salary | Numerical |
# | Exited | Customer churn status (1 = Left, 0 = Stayed) | Categorical |

# %% [markdown]
# # **Preliminary Data Exploration**

# %%
df.shape

df.info()

df.describe()

df.isnull().sum()

df.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB
# RowNumber          10000
# CustomerId         10000
# ...

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# # **8.1 Column Handling**

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1, inplace=True)

# %% [markdown]
# # **8.2 Data Type Conversion**

# %%
df['Gender'] = df['Gender'].astype('category')

df['Geography'] = df['Geography'].astype('category')

# %% [markdown]
# # **Data Cleaning and Preperation**

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## **Data Visualization and Analysis**

# %% [markdown]
# **1. Churn Distribution**

# %%
sns.countplot(x='Exited', data=df)
plt.title('Customer Churn Distribution')
plt.show()

# %% [markdown]
# **2. Gender vs Churn**

# %%
sns.countplot(x='Gender', hue='Exited', data=df)
plt.title('Gender vs Churn')
plt.show()

# %% [markdown]
# **3. Geography vs Churn**

# %%
sns.countplot(x='Geography', hue='Exited', data=df)
plt.title('Geography vs Churn')
plt.show()

# %% [markdown]
# **4. Age Distribution**

# %%
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# **5. Age vs Churn**

# %%
sns.boxplot(x='Exited', y='Age', data=df)
plt.title('Age vs Churn')
plt.show()

# %% [markdown]
# **6. Balance Distribution**

# %%
sns.histplot(df['Balance'], kde=True)
plt.title('Balance Distribution')
plt.show()

# %% [markdown]
# **7. Balance vs Churn**

# %%
sns.boxplot(x='Exited', y='Balance', data=df)
plt.title('Balance vs Churn')
plt.show()

# %% [markdown]
# **8. Credit Score Distribution**

# %%
sns.histplot(df['CreditScore'], kde=True)
plt.title('Credit Score Distribution')
plt.show()

# %% [markdown]
# **9. Credit Score vs Churn**

# %%
sns.boxplot(x='Exited', y='CreditScore', data=df)
plt.title('Credit Score vs Churn')
plt.show()

# %% [markdown]
# **10. Salary vs Churn**

# %%
sns.boxplot(x='Exited', y='EstimatedSalary', data=df)
plt.title('Salary vs Churn')
plt.show()

# %% [markdown]
# **11. Tenure vs Churn**

# %%
sns.boxplot(x='Exited', y='Tenure', data=df)
plt.title('Tenure vs Churn')
plt.show()

# %% [markdown]
# **12. Active Member vs Churn**

# %%
sns.countplot(x='IsActiveMember', hue='Exited', data=df)
plt.title('Active Membership vs Churn')
plt.show()

# %% [markdown]
# **13. Products vs Churn**

# %%
sns.countplot(x='NumOfProducts', hue='Exited', data=df)
plt.title('Products vs Churn')
plt.show()

# %% [markdown]
# **14. Age vs Balance Scatter**

# %%
sns.scatterplot(x='Age', y='Balance', hue='Exited', data=df)
plt.title('Age vs Balance')
plt.show()

# %% [markdown]
# **15. Violin Plot (Age vs Churn)**

# %%
sns.violinplot(x='Exited', y='Age', data=df)
plt.title('Age Distribution by Churn')
plt.show()

# %% [markdown]
# **16. Credit Card vs Churn**

# %%
sns.countplot(x='HasCrCard', hue='Exited', data=df)
plt.title('Credit Card vs Churn')
plt.show()

# %% [markdown]
# **17. Pair Plot**

# %%
sns.pairplot(df[['Age','Balance','CreditScore','EstimatedSalary','Exited']], hue='Exited')

# %% [markdown]
# **18.Correlation Heatmap**

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **19. Salary Distribution**

# %%
sns.histplot(df['EstimatedSalary'], kde=True)
plt.title('Salary Distribution')
plt.show()

# %% [markdown]
# **20. Products Distribution**

# %%
sns.countplot(x='NumOfProducts', data=df)
plt.title('Product Distribution')
plt.show()

# %% [markdown]
# # **Key Insights Summary**

# %% [markdown]
# Older customers show higher churn rates
#
# Customers with high balances are more likely to leave
#
# Inactive members churn significantly more
#
# Geography influences churn patterns
#
# Number of products impacts customer retention

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# EDA shows that age, balance, and customer activity strongly influence churn. Understanding these factors helps banks design retention strategies.

# %% [markdown]
# # **Recommendations**

# %% [markdown]
# Focus retention programs on older customers
#
# Provide incentives for high-balance customers
#
# Increase engagement for inactive members
#
# Develop region-specific customer strategies
